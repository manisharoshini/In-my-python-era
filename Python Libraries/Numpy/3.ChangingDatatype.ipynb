# %% [markdown]
# * CHANGING DATATYPE

# %%
import numpy as np

# %%
a1 = np.arange(8).reshape(2,2,2)
print(a1)
# Out:
# [[[0 1]
#   [2 3]]
#
#  [[4 5]
#   [6 7]]]

# %%
a1.astype(np.int32)
# Out:
# array([[[0, 1],
#         [2, 3]],
#
#        [[4, 5],
#         [6, 7]]], dtype=int32)
