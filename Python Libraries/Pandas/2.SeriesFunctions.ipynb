# %% [markdown]
# **SERIES USING readcsv**

# %% [markdown]
# The series is created with existig dataset ie. Real world datasets
#
# Read_csv - csv is an excel like data known as comma seperated files. this function extracts data from csv files.

# %%
import pandas as pd

# %% [markdown]
# Dataset with one column

# %%
subs = pd.read_csv('Datasets/subs.csv')
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
type(subs) # the dataset by defaulty stores data in the form of the DataFrame not Series. we have to explicitly convert datasets into dataframe
# Out:
# pandas.DataFrame

# %%
# To explicitly convert datasets in the form of Series 
subs = subs.squeeze() # squeeze() - converts dataFrame into Series
print(type(subs))
# Out:
# <class 'pandas.Series'>

# %% [markdown]
# Dataset with 2 columns

# %%
ipl = pd.read_csv('Datasets/kohli_ipl.csv',index_col='match_no').squeeze()
ipl

# here the index is not generated automatically we provided the index of the series
# here the name of series is runs -- The column that we kept as values is the name of the series
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
type(ipl)
# Out:
# pandas.Series

# %% [markdown]
# Dataset import

# %%
bollywood = pd.read_csv('Datasets/bollywood.csv',index_col='movie').squeeze()
bollywood

# here the index is movie name and the value of the index is the name of lead actor
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %% [markdown]
# ## **SERIES METHODS**

# %% [markdown]
# 1. Head and Tail method

# %%
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
subs.head(3)
# Out:
# 0    48
# 1    57
# 2    40
# Name: Subscribers gained, dtype: int64

# %%
ipl.tail()
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
ipl.tail(10)
# Out:
# match_no
# 206     0
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %% [markdown]
# 2. Sample Method

# %%
bollywood.sample()
# Out:
# movie
# Sandwich (2006 film)    Govinda
# Name: lead, dtype: str

# %%
bollywood.sample(5)
# Out:
# movie
# Jhoom Barabar Jhoom                 Abhishek Bachchan
# Raaz (2002 film)                           Dino Morea
# Ab Tumhare Hawale Watan Saathiyo     Amitabh Bachchan
# Qarib Qarib Singlle                       Irrfan Khan
# Aarakshan                            Amitabh Bachchan
# Name: lead, dtype: str

# %% [markdown]
# 4. Value_counts --> movies

# %%
# Each actor did how many movies (count of movies of each actor)
bollywood.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Tanishaa Mukerji     1
# Tanuja               1
# Ankit                1
# Rakhee Gulzar        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %% [markdown]
# 5. sort_values --> inplace

# %%
ipl.sort_values()
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
ipl.sort_values(ascending=False)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
#       ...
# 93       0
# 130      0
# 206      0
# 207      0
# 211      0
# Name: runs, Length: 215, dtype: int64

# %%
# if we want to print inlt top row 
ipl.sort_values(ascending=False).head(1)
# Out:
# match_no
# 128    113
# Name: runs, dtype: int64

# %%
# if we want to prient only number:
ipl.sort_values(ascending=False).head(1).values
# Out:
# array([113])

# %%
# if we want only the number not the array:

ipl.sort_values(ascending=False).head(1).values[0] 
# --> this is known as method chaining -- The output of first method becomes the input of next method  and the output then becomes input of next methods4

"""this only did temproary changes in the series -- if we wanto change the original series -- we use ipl.sort_values(inplace = True)"""
# Out:
# 'this only did temproary changes in the series -- if we wanto change the original series -- we use ipl.sort_values(inplace = True)'

# %% [markdown]
# 6. Sort_index -> inplace -> movies

# %%
# if we want to store movies alphabetically:

bollywood.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: str

# %%
# if we wanr to store data in descending order :

bollywood.sort_index(ascending=False) # This will print data in descending format
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)              Arjun Kapoor
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: str

# %% [markdown]
# ## **SERIES MATHEMATICAL METHODS**

# %% [markdown]
# count -- This counts the total number of items in series (size also does the same)
#
# count --> doesnt counts the missing values.. but size also counts missing values.
#
# defn : count gives you the total number of non-missing values in series.

# %%
# if we ant caluculate total matches in ipl dataset
ipl.count() # -- total number of rows are the matches played.
# Out:
# np.int64(215)

# %% [markdown]
# Sum and Product

# %%
# in subs dataset --  how many subscribers gained in one year:
subs.sum() # -- calcu;ates the sum of values
# Out:
# np.int64(49510)

# %%
subs.product()
# Out:
# np.int64(0)

# %% [markdown]
# Mean, Median, Mode, Standard Deviation, Variance

# %%
# On an average how many subscirbers do i get a year:

subs.mean() # -- on daily basis we are gaining 135 subs
# Out:
# np.float64(135.64383561643837)

# %%
# Median ipl score:
ipl.median()
# Out:
# np.float64(24.0)

# %%
# Mode - most repeated values
# which actor did most of the movies:
bollywood.mode() # -- 0 is the index given to akshay kumar
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: str

# %%
# standard Devaition:
subs.std()
# Out:
# np.float64(62.6750230372527)

# %%
# Variance:

ipl.var()
# Out:
# np.float64(688.0024777222343)

# %% [markdown]
# Min and Max

# %%
# maximum subscriber gained: 
subs.max()
# Out:
# np.int64(396)

# %%
# minimum subscriber gained:
subs.min()
# Out:
# np.int64(33)

# %% [markdown]
# Describe - gives the summary of the dataset

# %%
ipl.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
bollywood.describe()
# Out:
# count             1500
# unique             566
# top       Akshay Kumar
# freq                48
# Name: lead, dtype: object

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# # **SERIES INDEXING**

# %%
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %% [markdown]
# **Integer Indexing**

# %%
# First item from the series X
print(f"The First item of the series x: {x[0]}")

# Second item from the series X
print(f"The Second item of the Series x: {x[1]}")
# Out:
# The First item of the series x: 12
# The Second item of the Series x: 13

# %%
bollywood['Zokkomon'] # -- bollywood[0] is not possible coz here the name of the index is a movie name that we have given
# Out:
# 'Darsheel Safary'

# %% [markdown]
# **Negative Indexing** - Not possible in Series (only possible in Numpy array)

# %% [markdown]
# # **SLICING**
#
# Slicing - Fetching multiple items in a single go

# %%
# Check the runs between 5 to 15 matches:
ipl[4:15]
# Out:
# match_no
# 5      1
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# Name: runs, dtype: int64

# %% [markdown]
# **Negative Indexing**

# %%
ipl[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# last 5 movies:

bollywood[-5:]
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: str

# %%
# Alternate Movies:

bollywood[::2]
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# The Accidental Prime Minister (film)         Anupam Kher
# Evening Shadows                         Mona Ambegaonkar
# Fraud Saiyaan                               Arshad Warsi
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
#                                               ...
# Raaz (2002 film)                              Dino Morea
# Waisa Bhi Hota Hai Part II                  Arshad Warsi
# Kaante                                  Amitabh Bachchan
# Aankhen (2002 film)                     Amitabh Bachchan
# Company (film)                                Ajay Devgn
# Name: lead, Length: 750, dtype: str

# %% [markdown]
# Slicing works in the same way as in numpy !!!

# %% [markdown]
# **Fancy Indexing**

# %%
# if we want runs of 1st,3rd ,5th and 6th match 
ipl[[1,3,4,5]]
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %% [markdown]
# **Indexing with Labels --> fancy Indexing**

# %%
bollywood['Awara Paagal Deewana'] # -- we can also give string indexing
# Out:
# 'Akshay Kumar'
